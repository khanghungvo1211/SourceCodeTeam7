# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load data
#get the data
df = pd.read_csv("/content/BTC-USD (2).csv")
df
# Out:
#             Date         Open         High          Low     Close  \
# 0     12/26/2017  14036.59961  16461.19922  14028.90039  16099.80
# 1     12/27/2017  16163.50000  16930.90039  15114.29981  15838.50
# 2     12/28/2017  15864.09961  15888.40039  13937.29981  14606.50
# 3     12/29/2017  14695.79981  15279.00000  14307.00000  14656.20
# 4     12/30/2017  14681.90039  14681.90039  12350.09961  12952.20
# ...          ...          ...          ...          ...       ...
# 1822  12/22/2022  16818.38086  16866.67383  16592.40820  16830.34
# 1823  12/23/2022  16829.64453  16905.21875  16794.45898  16796.95
# 1824  12/24/2022  16796.97656  16864.70313  16793.52734  16847.76
# 1825  12/25/2022  16847.50586  16860.55469  16755.25391  16841.99
# 1826  12/26/2022  16839.71289  16907.52539  16831.09375  16848.80
#
#         Adj Close        Volume
# 0     16099.79981  1.345430e+10
# 1     15838.50000  1.248760e+10
# 2     14606.50000  1.233650e+10
# 3     14656.20020  1.302550e+10
# 4     12952.20020  1.445260e+10
# ...           ...           ...
# 1822  16830.34180  1.644157e+10
# 1823  16796.95313  1.532927e+10
# 1824  16847.75586  9.744636e+09
# 1825  16841.98633  1.165638e+10
# 1826  16848.79688  1.241912e+10
#
# [1827 rows x 7 columns]

# %%
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['Close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv("/content/BTC-USD (2).csv")
df
# Out:
#             Date         Open         High           Low     Close  \
# 20     1/15/2018  13767.29981  14445.50000  13641.700200  13819.80
# 21     1/16/2018  13836.09961  13843.09961  10194.900390  11490.50
# 22     1/17/2018  11431.09961  11678.00000   9402.290039  11188.60
# 23     1/18/2018  11198.79981  12107.29981  10942.500000  11474.90
# 24     1/19/2018  11429.79981  11992.79981  11172.099610  11607.40
# ...          ...          ...          ...           ...       ...
# 1822  12/22/2022  16818.38086  16866.67383  16592.408200  16830.34
# 1823  12/23/2022  16829.64453  16905.21875  16794.458980  16796.95
# 1824  12/24/2022  16796.97656  16864.70313  16793.527340  16847.76
# 1825  12/25/2022  16847.50586  16860.55469  16755.253910  16841.99
# 1826  12/26/2022  16839.71289  16907.52539  16831.093750  16848.80
#
#         Adj Close        Volume          H-L         O-C         SMA_7  \
# 20    13819.79981  1.275080e+10   803.799800   -52.50019  14129.585714
# 21    11490.50000  1.885380e+10  3648.199220  2345.59961  13686.028571
# 22    11188.59961  1.883060e+10  2275.709961   242.49961  13145.357143
# 23    11474.90039  1.502040e+10  1164.799810  -276.10019  12869.514286
# 24    11607.40039  1.074040e+10   820.700200  -177.60019  12530.485714
# ...           ...           ...          ...         ...           ...
# 1822  16830.34180  1.644157e+10   274.265630   -11.95914  16742.058571
# 1823  16796.95313  1.532927e+10   110.759770    32.69453  16763.411429
# 1824  16847.75586  9.744636e+09    71.175790   -50.78344  16770.935714
# 1825  16841.98633  1.165638e+10   105.300780     5.51586  16782.937143
# 1826  16848.79688  1.241912e+10    76.431640    -9.08711  16841.382857
#
#             SMA_14        SMA_21         SD_7        SD_21
# 20    15092.400000  14917.161905   540.357432  1239.058043
# 21    14843.000000  14697.671429  1089.534061  1414.867099
# 22    14556.400000  14476.247619  1268.615347  1581.446680
# 23    14261.807143  14327.123810  1405.126389  1710.900315
# 24    13845.942857  14181.942857  1378.412094  1808.170022
# ...            ...           ...          ...          ...
# 1822  17052.053571  17047.717619   154.870933   330.000116
# 1823  17028.039286  17033.826667   149.881278   334.302073
# 1824  17007.970714  17030.946667   153.025723   335.695705
# 1825  16989.242143  17017.208571   155.120304   337.317687
# 1826  16963.696429  17011.207143    34.095433   339.225115
#
# [1807 rows x 14 columns]

# %%
pre_day = 30
#feature scaling (MinMax Scaler)
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))

cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))
#Split the data into x_train and y_train data sets
x_total = []
y_total = []
#create a loop of values
for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])
#Splitting the dataset
test_size = (int)(len(scaled_data_y) * 0.2)
print(test_size)

x_train = np.array(x_total[:len(x_total)-test_size])
x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)-test_size])
y_test = np.array(y_total[len(y_total)-test_size:])

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# 361
# (1416, 30, 7) (1416, 1) (361, 30, 7) (361, 1)

# %%
# Build model
model = Sequential()
#5 layers lstm, and first lstm connect input information
model.add(LSTM(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))
#trainning model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=100, steps_per_epoch=40, use_multiprocessing=True)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 12s 14ms/step - loss: 0.0148
# Epoch 2/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0058
# Epoch 3/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0051
# Epoch 4/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0051
# Epoch 5/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0049
# Epoch 6/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0044
# Epoch 7/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0044
# Epoch 8/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0038
# Epoch 9/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0034
# Epoch 10/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0041
# Epoch 11/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0038
# Epoch 12/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0039
# Epoch 13/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0029
# Epoch 14/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0027
# Epoch 15/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0024
# Epoch 16/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 17/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 18/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 19/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0019
# Epoch 20/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 21/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0019
# Epoch 22/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 23/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 24/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 25/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 26/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 27/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 28/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 29/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 30/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 31/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 32/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 33/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 34/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 35/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 36/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 37/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0016
# Epoch 38/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 39/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 40/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 41/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 42/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 43/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 44/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 45/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 46/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 47/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 48/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0016
# Epoch 49/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 50/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 51/100
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0010
# Epoch 52/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 53/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 54/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 55/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 56/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 57/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 58/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 59/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0010
# Epoch 60/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 61/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 62/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 63/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 64/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.3750e-04
# Epoch 65/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 66/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 67/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 68/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0011
# Epoch 69/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.3892e-04
# Epoch 70/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.8939e-04
# Epoch 71/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 72/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 73/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 74/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 75/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 76/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 77/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.0985e-04
# Epoch 78/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.8331e-04
# Epoch 79/100
# 40/40 [==============================] - 0s 12ms/step - loss: 8.7880e-04
# Epoch 80/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 81/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 82/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 83/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.0667e-04
# Epoch 84/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 85/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.5573e-04
# Epoch 86/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.4268e-04
# Epoch 87/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 88/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 89/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.7941e-04
# Epoch 90/100
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 91/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 92/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 93/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.9486e-04
# Epoch 94/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.9775e-04
# Epoch 95/100
# 40/40 [==============================] - 0s 12ms/step - loss: 8.7882e-04
# Epoch 96/100
# 40/40 [==============================] - 0s 12ms/step - loss: 8.6179e-04
# Epoch 97/100
# 40/40 [==============================] - 0s 12ms/step - loss: 9.3068e-04
# Epoch 98/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 99/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 100/100
# 40/40 [==============================] - 0s 12ms/step - loss: 8.7656e-04

# %%
# Testing
predict_price = model.predict(x_test)
predict_price = scala_y.inverse_transform(predict_price)
# Out:
# 12/12 [==============================] - 1s 6ms/step

# %%
# Ploting the stat
real_price = df[len(df)-test_size:]['Close'].values.reshape(-1,1)
real_price = np.array(real_price)
print(real_price.shape)
real_price = real_price.reshape(real_price.shape[0], 1)

plt.figure(figsize=(20,10))
plt.plot(real_price, color="red", label=f"Real BTC Prices") # real price line
plt.plot(predict_price, color="blue", label=f"Predicted BTC Prices") # predict_price line
plt.title(f"BTC Prices") # naming chart
plt.xlabel("Time (day)")
plt.ylabel("Stock Prices")
plt.legend() #note
plt.show()
# Out:
# (361, 1)

# %%
# Make Prediction
x_predict = df[len(df)-pre_day:][cols_x].values.reshape(-1, len(cols_x))
x_predict = scala_x.transform(x_predict)
x_predict = np.array(x_predict)
x_predict = x_predict.reshape(1, x_predict.shape[0], len(cols_x))

prediction = model.predict(x_predict)
prediction = scala_y.inverse_transform(prediction)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# [[16227.135]]

# %%
mae = mean_absolute_error(real_price, predict_price)
mape = mean_absolute_percentage_error(real_price, predict_price)
mse = mean_squared_error(real_price, predict_price)
rmse = np.sqrt(mse)
r2 = r2_score(real_price, predict_price)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 1351.58
# MAPE: 4.62%
# MSE: 3153266.28
# RMSE: 1775.74
# R2: 0.97
