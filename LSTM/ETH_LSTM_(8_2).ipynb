# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load data
#get the data
df = pd.read_csv("/content/ETH-USD.csv")
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2017-12-26   763.369995   786.789978   760.934998   773.835999
# 1     2017-12-27   774.969971   789.252991   738.413025   762.841980
# 2     2017-12-28   762.208008   763.318970   701.187012   737.023010
# 3     2017-12-29   740.388977   770.117004   729.607971   753.591980
# 4     2017-12-30   753.815002   753.815002   685.231018   717.257019
# ...          ...          ...          ...          ...          ...
# 1822  2022-12-22  1213.672607  1221.986816  1187.127808  1218.182129
# 1823  2022-12-23  1218.079346  1226.998779  1215.994873  1220.159424
# 1824  2022-12-24  1220.117920  1224.911621  1216.338745  1221.148560
# 1825  2022-12-25  1221.171509  1223.517822  1203.719604  1218.962036
# 1826  2022-12-26  1218.458252  1222.611572  1217.611328  1219.282593
#
#         Adj Close      Volume
# 0      773.835999  2201159936
# 1      762.841980  2100029952
# 2      737.023010  2389149952
# 3      753.591980  2648969984
# 4      717.257019  3187780096
# ...           ...         ...
# 1822  1218.182129  5297471739
# 1823  1220.159424  4835831923
# 1824  1221.148560  2626153345
# 1825  1218.962036  3942720070
# 1826  1219.282593  4167609088
#
# [1827 rows x 7 columns]

# %%
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['Close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv("/content/ETH-USD.csv")
df
# Out:
#             Date         Open         High          Low        Close  \
# 20    2018-01-15  1365.209961  1390.589966  1290.599976  1291.920044
# 21    2018-01-16  1292.630005  1292.630005   875.544983  1053.689941
# 22    2018-01-17  1061.339966  1090.229980   780.921997  1014.250000
# 23    2018-01-18  1016.440002  1100.310059   967.758972  1036.280029
# 24    2018-01-19  1028.819946  1093.219971  1003.710022  1039.099976
# ...          ...          ...          ...          ...          ...
# 1822  2022-12-22  1213.672607  1221.986816  1187.127808  1218.182129
# 1823  2022-12-23  1218.079346  1226.998779  1215.994873  1220.159424
# 1824  2022-12-24  1220.117920  1224.911621  1216.338745  1221.148560
# 1825  2022-12-25  1221.171509  1223.517822  1203.719604  1218.962036
# 1826  2022-12-26  1218.458252  1222.611572  1217.611328  1219.282593
#
#         Adj Close      Volume         H-L         O-C        SMA_7  \
# 20    1291.920044  4781100032   99.989990   73.289917  1291.257150
# 21    1053.689941  8405139968  417.085022  238.940064  1256.107143
# 22    1014.250000  8545160192  309.307983   47.089966  1221.597151
# 23    1036.280029  5938319872  132.551087  -19.840027  1204.647147
# 24    1039.099976  4084450048   89.509949  -10.280030  1171.204293
# ...           ...         ...         ...         ...          ...
# 1822  1218.182129  5297471739   34.859008   -4.509522  1194.031389
# 1823  1220.159424  4835831923   11.003906   -2.080078  1201.445679
# 1824  1221.148560  2626153345    8.572876   -1.030640  1206.159825
# 1825  1218.962036  3942720070   19.798218    2.209473  1211.052229
# 1826  1219.282593  4167609088    5.000244   -0.824341  1218.434047
#
#            SMA_14       SMA_21        SD_7       SD_21
# 20    1157.713292  1022.948097   78.528934  235.606771
# 21    1169.802290  1036.274475  118.826428  228.623030
# 22    1173.483006  1048.246286  149.931394  220.009060
# 23    1177.437151  1062.496620  164.703447  208.218453
# 24    1180.392866  1076.092239  172.066248  196.002826
# ...           ...          ...         ...         ...
# 1822  1237.400574  1246.970819   22.398817   44.464748
# 1823  1234.248762  1243.440156   20.991740   43.450536
# 1824  1231.017648  1242.383667   21.212311   43.722104
# 1825  1227.810041  1239.464879   19.305649   43.109022
# 1826  1223.857439  1237.541347    2.425886   43.063245
#
# [1807 rows x 14 columns]

# %%
pre_day = 30
#feature scaling (MinMax Scaler)
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))

cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))
#Split the data into x_train and y_train data sets
x_total = []
y_total = []
#create a loop of values
for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])
#Splitting the dataset
test_size = (int)(len(scaled_data_y) * 0.2)
print(test_size)

x_train = np.array(x_total[:len(x_total)-test_size])
x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)-test_size])
y_test = np.array(y_total[len(y_total)-test_size:])

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# 361
# (1416, 30, 7) (1416, 1) (361, 30, 7) (361, 1)

# %%
# Build model
model = Sequential()
#5 layers lstm, and first lstm connect input information
model.add(LSTM(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))
#trainning model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=100, steps_per_epoch=40, use_multiprocessing=True)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 11s 80ms/step - loss: 0.0136
# Epoch 2/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0049
# Epoch 3/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0043
# Epoch 4/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0035
# Epoch 5/100
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0035
# Epoch 6/100
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0040
# Epoch 7/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0031
# Epoch 8/100
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0033
# Epoch 9/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0028
# Epoch 10/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0029
# Epoch 11/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0035
# Epoch 12/100
# 40/40 [==============================] - 3s 85ms/step - loss: 0.0028
# Epoch 13/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0025
# Epoch 14/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0024
# Epoch 15/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0027
# Epoch 16/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0024
# Epoch 17/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0019
# Epoch 18/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0018
# Epoch 19/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0018
# Epoch 20/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0018
# Epoch 21/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0017
# Epoch 22/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0017
# Epoch 23/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0017
# Epoch 24/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0017
# Epoch 25/100
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0016
# Epoch 26/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0015
# Epoch 27/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0017
# Epoch 28/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0013
# Epoch 29/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0013
# Epoch 30/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0015
# Epoch 31/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0014
# Epoch 32/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0015
# Epoch 33/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0016
# Epoch 34/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0013
# Epoch 35/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0012
# Epoch 36/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0014
# Epoch 37/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0011
# Epoch 38/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0013
# Epoch 39/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0014
# Epoch 40/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0013
# Epoch 41/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0013
# Epoch 42/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0013
# Epoch 43/100
# 40/40 [==============================] - 3s 78ms/step - loss: 8.9693e-04
# Epoch 44/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0011
# Epoch 45/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0012
# Epoch 46/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0012
# Epoch 47/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0012
# Epoch 48/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0012
# Epoch 49/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0011
# Epoch 50/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0011
# Epoch 51/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0010
# Epoch 52/100
# 40/40 [==============================] - 3s 84ms/step - loss: 0.0013
# Epoch 53/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0011
# Epoch 54/100
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0012
# Epoch 55/100
# 40/40 [==============================] - 3s 79ms/step - loss: 8.8877e-04
# Epoch 56/100
# 40/40 [==============================] - 3s 81ms/step - loss: 8.8695e-04
# Epoch 57/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0010
# Epoch 58/100
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0011
# Epoch 59/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0011
# Epoch 60/100
# 40/40 [==============================] - 3s 78ms/step - loss: 9.1980e-04
# Epoch 61/100
# 40/40 [==============================] - 3s 77ms/step - loss: 8.2710e-04
# Epoch 62/100
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0010
# Epoch 63/100
# 40/40 [==============================] - 3s 81ms/step - loss: 9.4343e-04
# Epoch 64/100
# 40/40 [==============================] - 3s 79ms/step - loss: 8.8760e-04
# Epoch 65/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0011
# Epoch 66/100
# 40/40 [==============================] - 3s 81ms/step - loss: 8.1982e-04
# Epoch 67/100
# 40/40 [==============================] - 3s 78ms/step - loss: 8.6549e-04
# Epoch 68/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0011
# Epoch 69/100
# 40/40 [==============================] - 3s 78ms/step - loss: 9.0348e-04
# Epoch 70/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0012
# Epoch 71/100
# 40/40 [==============================] - 3s 78ms/step - loss: 9.3701e-04
# Epoch 72/100
# 40/40 [==============================] - 3s 80ms/step - loss: 7.9277e-04
# Epoch 73/100
# 40/40 [==============================] - 3s 82ms/step - loss: 9.4769e-04
# Epoch 74/100
# 40/40 [==============================] - 3s 80ms/step - loss: 9.7500e-04
# Epoch 75/100
# 40/40 [==============================] - 3s 77ms/step - loss: 8.4457e-04
# Epoch 76/100
# 40/40 [==============================] - 3s 80ms/step - loss: 9.3594e-04
# Epoch 77/100
# 40/40 [==============================] - 3s 78ms/step - loss: 7.7859e-04
# Epoch 78/100
# 40/40 [==============================] - 3s 80ms/step - loss: 8.1194e-04
# Epoch 79/100
# 40/40 [==============================] - 3s 77ms/step - loss: 8.6672e-04
# Epoch 80/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0011
# Epoch 81/100
# 40/40 [==============================] - 3s 78ms/step - loss: 8.1574e-04
# Epoch 82/100
# 40/40 [==============================] - 3s 80ms/step - loss: 9.8001e-04
# Epoch 83/100
# 40/40 [==============================] - 3s 78ms/step - loss: 9.2759e-04
# Epoch 84/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0010
# Epoch 85/100
# 40/40 [==============================] - 3s 78ms/step - loss: 7.8470e-04
# Epoch 86/100
# 40/40 [==============================] - 3s 82ms/step - loss: 9.8997e-04
# Epoch 87/100
# 40/40 [==============================] - 3s 78ms/step - loss: 8.7633e-04
# Epoch 88/100
# 40/40 [==============================] - 3s 79ms/step - loss: 8.1480e-04
# Epoch 89/100
# 40/40 [==============================] - 3s 81ms/step - loss: 9.7258e-04
# Epoch 90/100
# 40/40 [==============================] - 3s 82ms/step - loss: 9.2164e-04
# Epoch 91/100
# 40/40 [==============================] - 3s 78ms/step - loss: 8.3216e-04
# Epoch 92/100
# 40/40 [==============================] - 3s 78ms/step - loss: 8.2495e-04
# Epoch 93/100
# 40/40 [==============================] - 3s 81ms/step - loss: 8.9728e-04
# Epoch 94/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0010
# Epoch 95/100
# 40/40 [==============================] - 3s 84ms/step - loss: 9.2003e-04
# Epoch 96/100
# 40/40 [==============================] - 3s 76ms/step - loss: 7.2592e-04
# Epoch 97/100
# 40/40 [==============================] - 3s 79ms/step - loss: 8.0520e-04
# Epoch 98/100
# 40/40 [==============================] - 3s 81ms/step - loss: 7.6044e-04
# Epoch 99/100
# 40/40 [==============================] - 3s 81ms/step - loss: 6.3869e-04
# Epoch 100/100
# 40/40 [==============================] - 3s 77ms/step - loss: 7.1124e-04

# %%
# Testing
predict_price = model.predict(x_test)
predict_price = scala_y.inverse_transform(predict_price)
# Out:
# 12/12 [==============================] - 2s 20ms/step

# %%
# Ploting the stat
real_price = df[len(df)-test_size:]['Close'].values.reshape(-1,1)
real_price = np.array(real_price)
print(real_price.shape)
real_price = real_price.reshape(real_price.shape[0], 1)

plt.figure(figsize=(20,10))
plt.plot(real_price, color="red", label=f"Real ETH Prices") # real price line
plt.plot(predict_price, color="blue", label=f"Predicted ETH Prices") # predict_price line
plt.title(f"ETH Prices") # naming chart
plt.xlabel("Time (day)")
plt.ylabel("Stock Prices")
plt.legend() #note
plt.show()
# Out:
# (361, 1)

# %%
# Make Prediction
x_predict = df[len(df)-pre_day:][cols_x].values.reshape(-1, len(cols_x))
x_predict = scala_x.transform(x_predict)
x_predict = np.array(x_predict)
x_predict = x_predict.reshape(1, x_predict.shape[0], len(cols_x))

prediction = model.predict(x_predict)
prediction = scala_y.inverse_transform(prediction)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# [[1211.1829]]

# %%
mae = mean_absolute_error(real_price, predict_price)
mape = mean_absolute_percentage_error(real_price, predict_price)
mse = mean_squared_error(real_price, predict_price)
rmse = np.sqrt(mse)
r2 = r2_score(real_price, predict_price)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 220.78
# MAPE: 10.65%
# MSE: 90619.69
# RMSE: 301.03
# R2: 0.85
