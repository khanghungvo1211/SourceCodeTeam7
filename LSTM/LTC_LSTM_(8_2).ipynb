# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load data
#get the data
df = pd.read_csv("/content/LTC-USD.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-26  273.108002  289.510986  272.261993  286.503998  286.503998
# 1     2017-12-27  286.588989  290.944000  264.423004  272.174011  272.174011
# 2     2017-12-28  272.126007  273.177002  231.376999  249.929993  249.929993
# 3     2017-12-29  250.352005  258.040985  238.332993  245.501999  245.501999
# 4     2017-12-30  245.087006  245.432999  208.197006  218.962997  218.962997
# ...          ...         ...         ...         ...         ...         ...
# 1822  2022-12-22   65.399422   66.514549   64.517052   66.151672   66.151672
# 1823  2022-12-23   66.152802   66.596397   65.450348   65.772224   65.772224
# 1824  2022-12-24   65.772232   66.012245   65.263176   65.774788   65.774788
# 1825  2022-12-25   65.774750   69.363144   65.540604   69.206268   69.206268
# 1826  2022-12-26   69.206825   70.834938   68.710892   70.684746   70.684746
#
#           Volume
# 0      842993024
# 1      777137984
# 2     2593240064
# 3     1392210048
# 4      943667008
# ...          ...
# 1822   368489876
# 1823   306694378
# 1824   178396939
# 1825   335124962
# 1826   457389047
#
# [1827 rows x 7 columns]

# %%
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['Close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv("/content/LTC-USD.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 20    2018-01-15  237.289001  245.003998  232.774002  232.774002  232.774002
# 21    2018-01-16  232.817001  232.817001  152.292999  188.330994  188.330994
# 22    2018-01-17  190.145004  197.789993  141.007004  186.516006  186.516006
# 23    2018-01-18  186.949005  207.016006  176.830002  192.837006  192.837006
# 24    2018-01-19  191.192001  202.074997  186.938004  192.964005  192.964005
# ...          ...         ...         ...         ...         ...         ...
# 1822  2022-12-22   65.399422   66.514549   64.517052   66.151672   66.151672
# 1823  2022-12-23   66.152802   66.596397   65.450348   65.772224   65.772224
# 1824  2022-12-24   65.772232   66.012245   65.263176   65.774788   65.774788
# 1825  2022-12-25   65.774750   69.363144   65.540604   69.206268   69.206268
# 1826  2022-12-26   69.206825   70.834938   68.710892   70.684746   70.684746
#
#           Volume        H-L        O-C       SMA_7      SMA_14      SMA_21  \
# 20     601769984  12.229996   4.514999  242.059858  251.912857  250.522952
# 21    1405069952  80.524002  44.486007  233.673285  247.101928  245.848047
# 22    1422489984  56.782989   3.628998  224.530143  242.898214  241.769095
# 23     936784000  30.186004  -5.888001  219.311715  239.431572  239.050381
# 24     560284032  15.136993  -1.772004  213.041430  235.409644  236.548572
# ...          ...        ...        ...         ...         ...         ...
# 1822   368489876   1.997497  -0.752250   65.209958   70.512904   73.074049
# 1823   306694378   1.146049   0.380578   65.130733   69.758451   72.494084
# 1824   178396939   0.749069  -0.002556   65.247433   69.001579   71.978697
# 1825   335124962   3.822540  -3.431518   65.912024   68.471452   71.597363
# 1826   457389047   2.124046  -1.477921   66.961069   68.075968   71.141230
#
#            SD_7      SD_21
# 20    10.612533  20.588468
# 21    22.529358  23.012990
# 22    27.081103  25.563445
# 23    29.413042  27.606452
# 24    29.726382  29.319971
# ...         ...        ...
# 1822   1.036008   5.932171
# 1823   0.954354   6.026096
# 1824   0.979315   6.119666
# 1825   1.725026   6.025892
# 1826   2.094506   5.690292
#
# [1807 rows x 14 columns]

# %%
pre_day = 30
#feature scaling (MinMax Scaler)
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))

cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))
#Split the data into x_train and y_train data sets
x_total = []
y_total = []
#create a loop of values
for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])
#Splitting the dataset
test_size = (int)(len(scaled_data_y) * 0.2)
print(test_size)

x_train = np.array(x_total[:len(x_total)-test_size])
x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)-test_size])
y_test = np.array(y_total[len(y_total)-test_size:])

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# 361
# (1416, 30, 7) (1416, 1) (361, 30, 7) (361, 1)

# %%
# Build model
model = Sequential()
#5 layers lstm, and first lstm connect input information
model.add(LSTM(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))
#trainning model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=100, steps_per_epoch=40, use_multiprocessing=True)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 12s 89ms/step - loss: 0.0130
# Epoch 2/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0071
# Epoch 3/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0063
# Epoch 4/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0057
# Epoch 5/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0052
# Epoch 6/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0051
# Epoch 7/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0053
# Epoch 8/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0044
# Epoch 9/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0046
# Epoch 10/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0042
# Epoch 11/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0035
# Epoch 12/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0032
# Epoch 13/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0029
# Epoch 14/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0025
# Epoch 15/100
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0023
# Epoch 16/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0023
# Epoch 17/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0023
# Epoch 18/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0027
# Epoch 19/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0020
# Epoch 20/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0022
# Epoch 21/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0022
# Epoch 22/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0019
# Epoch 23/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0019
# Epoch 24/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0019
# Epoch 25/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0019
# Epoch 26/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0023
# Epoch 27/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0020
# Epoch 28/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0019
# Epoch 29/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0015
# Epoch 30/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0016
# Epoch 31/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0017
# Epoch 32/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0017
# Epoch 33/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0015
# Epoch 34/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0017
# Epoch 35/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0017
# Epoch 36/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0016
# Epoch 37/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0013
# Epoch 38/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0016
# Epoch 39/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0016
# Epoch 40/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0013
# Epoch 41/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0017
# Epoch 42/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0016
# Epoch 43/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0015
# Epoch 44/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0016
# Epoch 45/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0014
# Epoch 46/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0012
# Epoch 47/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0012
# Epoch 48/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0013
# Epoch 49/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0013
# Epoch 50/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0014
# Epoch 51/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0012
# Epoch 52/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0014
# Epoch 53/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0015
# Epoch 54/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0015
# Epoch 55/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0012
# Epoch 56/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0013
# Epoch 57/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0011
# Epoch 58/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0010
# Epoch 59/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0012
# Epoch 60/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0011
# Epoch 61/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0012
# Epoch 62/100
# 40/40 [==============================] - 4s 88ms/step - loss: 9.7281e-04
# Epoch 63/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0011
# Epoch 64/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0011
# Epoch 65/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0011
# Epoch 66/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0010
# Epoch 67/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0010
# Epoch 68/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0012
# Epoch 69/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0011
# Epoch 70/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0011
# Epoch 71/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0010
# Epoch 72/100
# 40/40 [==============================] - 4s 88ms/step - loss: 9.6554e-04
# Epoch 73/100
# 40/40 [==============================] - 4s 89ms/step - loss: 9.7841e-04
# Epoch 74/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0011
# Epoch 75/100
# 40/40 [==============================] - 4s 89ms/step - loss: 9.7569e-04
# Epoch 76/100
# 40/40 [==============================] - 4s 90ms/step - loss: 9.8273e-04
# Epoch 77/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0011
# Epoch 78/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0013
# Epoch 79/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0014
# Epoch 80/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0012
# Epoch 81/100
# 40/40 [==============================] - 4s 88ms/step - loss: 9.8237e-04
# Epoch 82/100
# 40/40 [==============================] - 4s 89ms/step - loss: 9.8186e-04
# Epoch 83/100
# 40/40 [==============================] - 4s 91ms/step - loss: 9.7299e-04
# Epoch 84/100
# 40/40 [==============================] - 4s 90ms/step - loss: 9.3102e-04
# Epoch 85/100
# 40/40 [==============================] - 4s 90ms/step - loss: 9.2794e-04
# Epoch 86/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0011
# Epoch 87/100
# 40/40 [==============================] - 4s 89ms/step - loss: 9.4223e-04
# Epoch 88/100
# 40/40 [==============================] - 4s 88ms/step - loss: 8.8146e-04
# Epoch 89/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0010
# Epoch 90/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0011
# Epoch 91/100
# 40/40 [==============================] - 4s 89ms/step - loss: 9.6655e-04
# Epoch 92/100
# 40/40 [==============================] - 4s 89ms/step - loss: 9.0047e-04
# Epoch 93/100
# 40/40 [==============================] - 4s 88ms/step - loss: 9.2843e-04
# Epoch 94/100
# 40/40 [==============================] - 4s 88ms/step - loss: 8.5987e-04
# Epoch 95/100
# 40/40 [==============================] - 4s 90ms/step - loss: 9.9668e-04
# Epoch 96/100
# 40/40 [==============================] - 3s 87ms/step - loss: 9.6801e-04
# Epoch 97/100
# 40/40 [==============================] - 4s 88ms/step - loss: 9.0316e-04
# Epoch 98/100
# 40/40 [==============================] - 4s 88ms/step - loss: 9.3822e-04
# Epoch 99/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0011
# Epoch 100/100
# 40/40 [==============================] - 4s 90ms/step - loss: 8.5179e-04

# %%
# Testing
predict_price = model.predict(x_test)
predict_price = scala_y.inverse_transform(predict_price)
# Out:
# 12/12 [==============================] - 2s 25ms/step

# %%
# Ploting the stat
real_price = df[len(df)-test_size:]['Close'].values.reshape(-1,1)
real_price = np.array(real_price)
print(real_price.shape)
real_price = real_price.reshape(real_price.shape[0], 1)

plt.figure(figsize=(20,10))
plt.plot(real_price, color="red", label=f"Real LTC Prices") # real price line
plt.plot(predict_price, color="blue", label=f"Predicted LTC Prices") # predict_price line
plt.title(f"LTC Prices") # naming chart
plt.xlabel("Time (day)")
plt.ylabel("Stock Prices")
plt.legend() #note
plt.show()
# Out:
# (361, 1)

# %%
# Make Prediction
x_predict = df[len(df)-pre_day:][cols_x].values.reshape(-1, len(cols_x))
x_predict = scala_x.transform(x_predict)
x_predict = np.array(x_predict)
x_predict = x_predict.reshape(1, x_predict.shape[0], len(cols_x))

prediction = model.predict(x_predict)
prediction = scala_y.inverse_transform(prediction)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[68.554184]]

# %%
mae = mean_absolute_error(real_price, predict_price)
mape = mean_absolute_percentage_error(real_price, predict_price)
mse = mean_squared_error(real_price, predict_price)
rmse = np.sqrt(mse)
r2 = r2_score(real_price, predict_price)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 3.58
# MAPE: 4.61%
# MSE: 24.03
# RMSE: 4.90
# R2: 0.97
