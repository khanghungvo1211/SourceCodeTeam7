# %% [markdown]
# ## Time Series Analysis SARIMA Model

# %%
#Import the necessary libraries and modules
import numpy as np
import pandas as pd
from plotly import graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the datatset
data = pd.read_csv(r"C:\BTC-USD.csv")
data
# Out:
#             Date          Open          High           Low         Close  \
# 0     2017-12-26  14036.599609  16461.199219  14028.900391  16099.799805
# 1     2017-12-27  16163.500000  16930.900391  15114.299805  15838.500000
# 2     2017-12-28  15864.099609  15888.400391  13937.299805  14606.500000
# 3     2017-12-29  14695.799805  15279.000000  14307.000000  14656.200195
# 4     2017-12-30  14681.900391  14681.900391  12350.099609  12952.200195
# ...          ...           ...           ...           ...           ...
# 1822  2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 1823  2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 1824  2022-12-24  16796.976563  16864.703125  16793.527344  16847.755859
# 1825  2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 1826  2022-12-26  16839.712891  16907.525391  16831.093750  16848.796875
#
#          Adj Close       Volume
# 0     16099.799805  13454300160
# 1     15838.500000  12487600128
# 2     14606.500000  12336499712
# 3     14656.200195  13025500160
# 4     12952.200195  14452599808
# ...            ...          ...
# 1822  16830.341797  16441573050
# 1823  16796.953125  15329265213
# 1824  16847.755859   9744636213
# 1825  16841.986328  11656379938
# 1826  16848.796875  12419123200
#
# [1827 rows x 7 columns]

# %% [markdown]
# ## Explanatory Data Analysis

# %%
data.describe().T
# Out:
#             count          mean           std           min           25%  \
# Open       1827.0  2.033123e+04  1.698843e+04  3.236275e+03  7.688712e+03
# High       1827.0  2.083343e+04  1.743165e+04  3.275378e+03  7.915483e+03
# Low        1827.0  1.976166e+04  1.647395e+04  3.191303e+03  7.518761e+03
# Close      1827.0  2.033037e+04  1.698341e+04  3.236762e+03  7.684072e+03
# Adj Close  1827.0  2.033037e+04  1.698341e+04  3.236762e+03  7.684072e+03
# Volume     1827.0  2.658843e+10  1.982448e+10  2.923670e+09  1.259719e+10
#
#                     50%           75%           max
# Open       1.097325e+04  3.376738e+04  6.754973e+04
# High       1.130440e+04  3.477808e+04  6.878962e+04
# Low        1.065646e+04  3.226580e+04  6.638206e+04
# Close      1.097018e+04  3.373452e+04  6.756683e+04
# Adj Close  1.097018e+04  3.373452e+04  6.756683e+04
# Volume     2.432216e+10  3.580014e+10  3.509679e+11

# %%
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.corr
# Out:
# <bound method DataFrame.corr of             Date          Open          High           Low         Close  \
# 0     2017-12-26  14036.599609  16461.199219  14028.900391  16099.799805
# 1     2017-12-27  16163.500000  16930.900391  15114.299805  15838.500000
# 2     2017-12-28  15864.099609  15888.400391  13937.299805  14606.500000
# 3     2017-12-29  14695.799805  15279.000000  14307.000000  14656.200195
# 4     2017-12-30  14681.900391  14681.900391  12350.099609  12952.200195
# ...          ...           ...           ...           ...           ...
# 1822  2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 1823  2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 1824  2022-12-24  16796.976563  16864.703125  16793.527344  16847.755859
# 1825  2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 1826  2022-12-26  16839.712891  16907.525391  16831.093750  16848.796875
#
#          Adj Close       Volume
# 0     16099.799805  13454300160
# 1     15838.500000  12487600128
# 2     14606.500000  12336499712
# 3     14656.200195  13025500160
# 4     12952.200195  14452599808
# ...            ...          ...
# 1822  16830.341797  16441573050
# 1823  16796.953125  15329265213
# 1824  16847.755859   9744636213
# 1825  16841.986328  11656379938
# 1826  16848.796875  12419123200
#
# [1827 rows x 7 columns]>

# %%
data2 = data.copy()

# %%
plt.figure(figsize=(20,12))
plt.subplot(2, 1, 1)
plt.title('Bitcoin Price')
plt.plot(data.Close,label='Close price')
plt.legend()

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# **Since we are particularly interested in the close price and date variable from the dataset, so we'll just copy these two variables into a new dataset**

# %%
df = data[['Date', 'Close']]
df
# Out:
#             Date         Close
# 0     2017-12-26  16099.799805
# 1     2017-12-27  15838.500000
# 2     2017-12-28  14606.500000
# 3     2017-12-29  14656.200195
# 4     2017-12-30  12952.200195
# ...          ...           ...
# 1822  2022-12-22  16830.341797
# 1823  2022-12-23  16796.953125
# 1824  2022-12-24  16847.755859
# 1825  2022-12-25  16841.986328
# 1826  2022-12-26  16848.796875
#
# [1827 rows x 2 columns]

# %% [markdown]
# **We need to group data for better understanding to it is advised to convert Date column into 'Datetime' type and extract needful information.**

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# Year              int64
# Month             int64
# dtype: object

# %%
df1= df.groupby(['Date'])['Close'].mean()
print(df1.head(10))
# Out:
# Date
# 2017-12-26    16099.799805
# 2017-12-27    15838.500000
# 2017-12-28    14606.500000
# 2017-12-29    14656.200195
# 2017-12-30    12952.200195
# 2017-12-31    14156.400391
# 2018-01-01    13657.200195
# 2018-01-02    14982.099609
# 2018-01-03    15201.000000
# 2018-01-04    15599.200195
# Name: Close, dtype: float64

# %%
plt.figure(figsize=(20,12))
plt.subplot(2, 1, 1)
plt.title('Bitcoin Price')
plt.plot(df.Close,label='Close price')
plt.legend()

# %% [markdown]
# ## Stationarity

# %% [markdown]
# **Stationarity in a time-series data is a very important feature as it becomes relatively easier and statistically more accurate to apply time series methodologies on a stationary series and thus derive the business decisions. A data is said to be stationary if the mean, variance and autocorrelation structure do not show any difference over time. In other words, the data should not contain any trends or seasonality and has to show a constant variance and autocorrelation structure over time.
# We will use ADF Test to acertain the stationarity of the Closing Price series.**

# %% [markdown]
# ### Augmented Dickey-Fuller (ADF) TEST

# %% [markdown]
# **The Augmented Dickey-Fuller Test (ADF) is a stationarity unit root test. The null hypothesis of ADF test is that series is non-stationary. Since ADF statistic is greater than critical values, we cannot reject the null hypothesis. Hence, this imply that the series is non-stationary.**

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series):
    ADF=adfuller(series)
    print(f'ADF Statistic is: {ADF[0]}')
    print(f'p-value is: {ADF[1]}')
    print(f'Number of lags: {ADF[2]}')
    print(f'Number of obs: {ADF[3]}')
    print(f'Critical Values: {ADF[4]}')
    if ADF[1] <= 0.05:
        print("Strong evidence against null hypothesis, so we reject null hypothesis")
    else:
        print("Weak evidence against null hypothesis implying we fail to reject null hypothesis")
        
adf_test(df['Close'])
# Out:
# ADF Statistic is: -1.369269882971864
# p-value is: 0.5969166728785437
# Number of lags: 24
# Number of obs: 1802
# Critical Values: {'1%': -3.4339840952648695, '5%': -2.8631452508003057, '10%': -2.567624583142913}
# Weak evidence against null hypothesis implying we fail to reject null hypothesis

# %% [markdown]
# ### Plotting the rolling statistics against original series

# %%
rolling_mean = df['Close'].rolling(12).mean()
rolling_std = df['Close'].rolling(12).std()

#Plot rolling statistics:
plt.figure(figsize=(10,8))
plt.plot(df['Close'], color='blue',label='Original')
plt.plot(rolling_mean, color='red', label='Rolling Mean')
plt.plot(rolling_std, color='black', label = 'Rolling Std')
plt.legend()
plt.title('Rolling Mean and Standard Deviation')
plt.show()

# %% [markdown]
# **Through the above graph, we can see that standard deviation is fairly constant in the series but increasing mean implies the non-stationarity of the series.**

# %% [markdown]
# ### Tranforming the series into Stationary

# %% [markdown]
# **There are multiple ways of transforming the a non-stationary series into stationary:**
# 1. Differencing
# 2. Scale transformation : Using log or sqaure root of the data
# 3. Seasonal Decomposition

# %% [markdown]
# #### First Differencing

# %%
df['Close_FD'] = df['Close']-df['Close'].shift(1)
df['Close_FD'].isnull().sum()
# Out:
# 1

# %%
df['Close_FD'] = df['Close_FD'].fillna(0)

# %%
adf_test(df['Close_FD'])
# Out:
# ADF Statistic is: -12.893133531655039
# p-value is: 4.4053646512059054e-24
# Number of lags: 14
# Number of obs: 1812
# Critical Values: {'1%': -3.4339640110318004, '5%': -2.8631363845692475, '10%': -2.567619862152732}
# Strong evidence against null hypothesis, so we reject null hypothesis

# %%
df['Close_FD'].plot(figsize=(15,8), title= "First Difference of Closing Price")
# Out:
# <AxesSubplot:title={'center':'First Difference of Closing Price'}>

# %% [markdown]
# **After first differencing we got the stationarity in the closing price.**

# %%
FDrolling_mean = df['Close_FD'].rolling(30).mean()
FDrolling_std = df['Close_FD'].rolling(30).std()

#Plot rolling statistics:
plt.figure(figsize=(15,8))
plt.plot(df['Close_FD'], color='blue',label='Original')
plt.plot(FDrolling_mean, color='red', label='Rolling Mean')
plt.plot(FDrolling_std, color='black', label = 'Rolling Std')
plt.legend()
plt.title('Rolling Mean and Standard Deviation of first differnce of closing price')
plt.show()

# %% [markdown]
# **The rolling mean and standard deviation are in line with the average trend in the series.**

# %% [markdown]
# #### Seasonal Decomposition

# %% [markdown]
# **Seasoanlity is a cyclic event that occurs in time series for a short time and causes the increasing or decreasing patterns for a short time in a time series. There are two types of seasonality:**
#
# **-Additive time series: In this, the components of the time series are added together to make the time series. Visually, the increasing or decreasing pattern of the time series is similar throughout the series.**
#
# **-Multiplicative time series: In this, the components of the time series are multiplicative together. Visually, the time series is having exponential growth or decrement with time.**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df["Close"], 
                            model='multiplicative', period = 12)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(15, 10)

# %% [markdown]
# **As we see, the data contains the seasonality which we can capture using SARIMA model.**

# %% [markdown]
# ## ACF and PACF
# **The  autocorrelation function is the amount of correlation between a variable and a lag of itself whereas the partial autocorrelation is the amount of correlation between a variable and a lag of itself that is not explained by correlations at all lower-order-lags.
# ACF determines the order of MA part while PACF determines the AR part of the ARIMA model.**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

figure = plt.figure(figsize=(10,8))
ax1 = figure.add_subplot(2,1,1)
figure = plot_acf(df['Close_FD'], lags=50, ax=ax1)
ax2 = figure.add_subplot(2,1,2)
figure = plot_pacf(df['Close_FD'], lags=50, ax=ax2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **According to the ACF and PACF graphs, the ARIMA model of (5,1,2) would be the appropriate one for our analysis. However, to ascertain the parameters, we will use auto ARIMA model in the next section.**

# %% [markdown]
# ## Training and Testing Data

# %%
n = int(len(df1)*0.7)
df_train = pd.DataFrame(df1[:n]).rename(columns={'Close':'y_train'})
df_test = pd.DataFrame(df1[n:]).rename(columns={'Close':'y_test'})

# %%
df_train
# Out:
#                  y_train
# Date
# 2017-12-26  16099.799805
# 2017-12-27  15838.500000
# 2017-12-28  14606.500000
# 2017-12-29  14656.200195
# 2017-12-30  12952.200195
# ...                  ...
# 2021-06-21  31676.693359
# 2021-06-22  32505.660156
# 2021-06-23  33723.027344
# 2021-06-24  34662.437500
# 2021-06-25  31637.779297
#
# [1278 rows x 1 columns]

# %%
df_train
# Out:
#                  y_train
# Date
# 2017-12-26  16099.799805
# 2017-12-27  15838.500000
# 2017-12-28  14606.500000
# 2017-12-29  14656.200195
# 2017-12-30  12952.200195
# ...                  ...
# 2021-06-21  31676.693359
# 2021-06-22  32505.660156
# 2021-06-23  33723.027344
# 2021-06-24  34662.437500
# 2021-06-25  31637.779297
#
# [1278 rows x 1 columns]

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Closing Price')
plt.plot(df_test, 'blue', label='Test data')
plt.plot(df_train, 'green', label='Train data')

plt.legend()

# %% [markdown]
# ## SARIMA Model

# %% [markdown]
# ### Building the Model

# %%
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import pmdarima as pm

# %%
# auto_arima
model_fit = pm.auto_arima(df_train, test='adf', 
                         max_p=5, max_d=2, max_q=5, 
                         seasonal=True, m=12,
                         max_P=5, max_D=5, max_Q=5,
                         trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

# summarize the model characteristics
print(model_fit.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=20868.442, Time=1.34 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=20913.052, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=20883.579, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=20887.322, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=20911.302, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=20881.680, Time=0.92 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=20879.063, Time=1.30 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=20870.440, Time=3.34 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=20870.440, Time=3.39 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=20901.281, Time=0.44 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=20879.445, Time=2.27 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=20876.206, Time=2.40 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=8.16 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=20866.480, Time=0.96 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=20879.703, Time=0.59 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=20877.081, Time=0.62 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=20868.478, Time=2.96 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=20868.479, Time=2.55 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=20899.320, Time=0.33 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=20877.489, Time=0.84 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=20874.260, Time=1.48 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=5.77 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=20866.413, Time=0.63 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=20879.175, Time=0.29 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=20876.553, Time=0.26 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=20868.409, Time=1.55 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=20868.410, Time=1.67 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=20898.938, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=20876.743, Time=0.65 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=20873.594, Time=0.62 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=4.72 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=20873.709, Time=0.49 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=20866.178, Time=0.78 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=20879.688, Time=0.35 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=20877.034, Time=0.28 sec
#  ARIMA(0,1,3)(2,0,1)[12] intercept   : AIC=20868.172, Time=1.61 sec
#  ARIMA(0,1,3)(1,0,2)[12] intercept   : AIC=20868.173, Time=2.02 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=20899.635, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=20877.253, Time=0.85 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=20873.953, Time=0.79 sec
#  ARIMA(0,1,3)(2,0,2)[12] intercept   : AIC=20868.260, Time=3.77 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=20868.055, Time=1.38 sec
#  ARIMA(0,1,4)(1,0,1)[12] intercept   : AIC=20867.908, Time=1.02 sec
#  ARIMA(1,1,4)(1,0,1)[12] intercept   : AIC=20869.851, Time=1.83 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=20864.398, Time=0.51 sec
#  ARIMA(0,1,3)(0,0,1)[12]             : AIC=20878.052, Time=0.20 sec
#  ARIMA(0,1,3)(1,0,0)[12]             : AIC=20875.381, Time=0.15 sec
#  ARIMA(0,1,3)(2,0,1)[12]             : AIC=20866.392, Time=1.21 sec
#  ARIMA(0,1,3)(1,0,2)[12]             : AIC=20866.391, Time=1.23 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=20897.867, Time=0.10 sec
#  ARIMA(0,1,3)(0,0,2)[12]             : AIC=20875.541, Time=0.61 sec
#  ARIMA(0,1,3)(2,0,0)[12]             : AIC=20872.232, Time=0.36 sec
#  ARIMA(0,1,3)(2,0,2)[12]             : AIC=inf, Time=3.48 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=20864.678, Time=0.51 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=20866.267, Time=0.65 sec
#  ARIMA(0,1,4)(1,0,1)[12]             : AIC=20866.124, Time=0.65 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=20864.735, Time=0.69 sec
#  ARIMA(1,1,4)(1,0,1)[12]             : AIC=20868.053, Time=1.31 sec
#
# Best model:  ARIMA(0,1,3)(1,0,1)[12]
# Total fit time: 77.719 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                 1278
# Model:             SARIMAX(0, 1, 3)x(1, 0, [1], 12)   Log Likelihood              -10426.199
# Date:                              Wed, 04 Jan 2023   AIC                          20864.398
# Time:                                      20:40:26   BIC                          20895.311
# Sample:                                  12-26-2017   HQIC                         20876.007
#                                        - 06-25-2021
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0555      0.015     -3.769      0.000      -0.084      -0.027
# ma.L2          0.0813      0.014      5.683      0.000       0.053       0.109
# ma.L3          0.0386      0.015      2.608      0.009       0.010       0.068
# ar.S.L12      -0.7435      0.065    -11.481      0.000      -0.870      -0.617
# ma.S.L12       0.6198      0.072      8.662      0.000       0.480       0.760
# sigma2       7.41e+05   1.08e+04     68.918      0.000     7.2e+05    7.62e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             12937.14
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.07   Skew:                            -0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import statsmodels.api as sm
import warnings


model=sm.tsa.statespace.SARIMAX(df['Close'],
                                order=(0, 1, 2),
                                seasonal_order=(1, 0, 1, 12))
model=model.fit()
print(model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Close   No. Observations:                 1827
# Model:             SARIMAX(0, 1, 2)x(1, 0, [1], 12)   Log Likelihood              -15210.434
# Date:                              Wed, 04 Jan 2023   AIC                          30430.868
# Time:                                      20:41:08   BIC                          30458.417
# Sample:                                           0   HQIC                         30441.030
#                                              - 1827
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0257      0.016     -1.660      0.097      -0.056       0.005
# ma.L2          0.0048      0.014      0.334      0.739      -0.023       0.033
# ar.S.L12      -0.7007      0.094     -7.469      0.000      -0.885      -0.517
# ma.S.L12       0.6278      0.101      6.223      0.000       0.430       0.826
# sigma2      1.017e+06    1.5e+04     68.030      0.000    9.88e+05    1.05e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              6310.49
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.39   Skew:                            -0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Predictions

# %%
start=len(df_train)
end=len(df_train)+len(df_test)-1
pred = model.predict(start=start,end=end)
pred
# Out:
# 1278    31742.986918
# 1279    32156.781908
# 1280    34725.750261
# 1281    34082.585339
# 1282    36036.666266
#             ...
# 1822    16829.765353
# 1823    16848.067940
# 1824    16808.940106
# 1825    16779.183138
# 1826    16815.531289
# Name: predicted_mean, Length: 549, dtype: float64

# %%
len(df_train)
# Out:
# 1278

# %%
len(df_test)
# Out:
# 549

# %%
# Generate prediction for n periods, 
# Predictions start from the last date of the training data
pred = model_fit.predict_in_sample(dynamic=False) # works only with auto-arima
df_train['y_train_pred'] = pred
test_pred = model_fit.predict(n_periods=n, dynamic=False)
df_test['y_test_pred'] = test_pred
df_union = pd.concat([df_train, df_test])
df_union.rename(columns={'Close':'y_test'}, inplace=True)

# Print the predicted time-series
fig, ax = plt.subplots(figsize=(20, 15))
plt.title("Test/Pred Comparison", fontsize=14)
sns.despine();
sns.lineplot(data=df_union[['y_train', 'y_train_pred', 'y_test', 'y_test_pred']], linewidth=1.0, dashes=False, palette='muted')
ax.set_xlim([df_union.index[100],df_union.index.max()])
plt.legend()

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
def mae(y_true, predictions):
    y_true, predictions = np.array(y_true), np.array(predictions)
    return np.mean(np.abs(y_true - predictions))
def mape(y_test, pred):
    y_test, pred = np.array(y_test), np.array(pred)
    mape = np.mean(np.abs((y_test - pred) / y_test))
    return mape

# %%
# Mean Absolute Percentage Error (MAPE)
mae = mae(df_test['y_test'], df_test['y_test_pred'])
print(f'MAE: {np.round(mae, 2)}')

# Median Absolute Percentage Error (MDAPE)
mape = mape(df_test['y_test'], df_test['y_test_pred'])*100
print(f'MAPE: {np.round(mape, 2)} %')

RMSE = np.sqrt(mean_squared_error(df_test['y_test'], df_test['y_test_pred']))
print(f'RMSE: {np.round(RMSE, 2)}')
# Out:
# MAE: 12343.49
# MAPE: 39.0 %
# RMSE: 14222.64
